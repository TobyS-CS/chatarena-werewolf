# %% [markdown]
# # Experiment 1
#
# Goal: run through a single game using llama 3 model on Delta.

# %%
# !pip uninstall chatarena -y
# !pip install -e .
# !pip install -U transformers
# !pip install accelerate
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///projects/bcti/commons/chatarena-werewolf
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for chatarena (pyproject.toml) ... done
#   Created wheel for chatarena: filename=chatarena-0.1.18-0.editable-py3-none-any.whl size=12327 sha256=68b2d6d5b3869a748f3a8e57754a88f905aecfc34afa616e056713ff3b60b54f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zv8m5po2/wheels/c3/9d/da/c8d435654a9a8d1f6098baf3fe340f7dc6c5cc4ebd7bf73415
# Successfully built chatarena
# ...
#   Attempting uninstall: chatarena
#     Found existing installation: chatarena 0.1.18
#     Uninstalling chatarena-0.1.18:
#       Successfully uninstalled chatarena-0.1.18
# ...

# %%
from chatarena.agent import Player, global_llama_backend
# Out:
# 2024-05-03 06:01:44.122867: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 06:01:44.122900: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 06:01:44.122921: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 06:01:44.130056: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# from chatarena.backends import TransformersConversational

# %%
environment_description = ""

# %%
player1 = Player(name="sai", backend=global_llama_backend,
                 role_desc="",
                 global_prompt="")
# Out:
# {'model': 'meta-llama/Meta-Llama-3-8B-Instruct', 'device': -1, 'backend_type': 'transformers:conversational'}

# %%
player2 = Player(name="adam", backend=global_llama_backend,
                 role_desc="",
                 global_prompt=environment_description)
player3 = Player(name="sid", backend=global_llama_backend,
                 role_desc="",
                 global_prompt=environment_description)
player4 = Player(name="julia", backend=global_llama_backend,
                 role_desc="",
                 global_prompt=environment_description)
player5 = Player(name="marie", backend=global_llama_backend,
                 role_desc="",
                 global_prompt=environment_description)
player6 = Player(name="toby", backend=global_llama_backend,
                 role_desc="",
                 global_prompt=environment_description)
player7 = Player(name="sean", backend=global_llama_backend,
                 role_desc="",
                 global_prompt=environment_description)
# Out:
# {'model': 'meta-llama/Meta-Llama-3-8B-Instruct', 'device': -1, 'backend_type': 'transformers:conversational'}
# {'model': 'meta-llama/Meta-Llama-3-8B-Instruct', 'device': -1, 'backend_type': 'transformers:conversational'}
# {'model': 'meta-llama/Meta-Llama-3-8B-Instruct', 'device': -1, 'backend_type': 'transformers:conversational'}
# {'model': 'meta-llama/Meta-Llama-3-8B-Instruct', 'device': -1, 'backend_type': 'transformers:conversational'}
# {'model': 'meta-llama/Meta-Llama-3-8B-Instruct', 'device': -1, 'backend_type': 'transformers:conversational'}
# {'model': 'meta-llama/Meta-Llama-3-8B-Instruct', 'device': -1, 'backend_type': 'transformers:conversational'}

# %%
# Describe the environment (which is shared by all players)
environment_description = ""

# player1 = Player(name="Alice", backend=TransformersConversational(),
#                  role_desc="",
#                  global_prompt=environment_description)
# player2 = Player(name="Bob", backend=TransformersConversational(),
#                  role_desc="",
#                  global_prompt=environment_description)
# player3 = Player(name="Carol", backend=TransformersConversational(),
#                  role_desc="",
#                  global_prompt=environment_description)


player2 = Player(name="Emily", backend=TransformersConversational(),
                 role_desc="",
                 global_prompt=environment_description)
player3 = Player(name="Fred", backend=TransformersConversational(),
                 role_desc="",
                 global_prompt=environment_description)

# player4 = Player(name="d", backend=TransformersConversational(),
#                  role_desc="",
#                  global_prompt=environment_description)
# player5 = Player(name="e", backend=TransformersConversational(),
#                  role_desc="",
#                  global_prompt=environment_description)
# player6 = Player(name="f", backend=TransformersConversational(),
#                  role_desc="",
#                  global_prompt=environment_description)

# # A "Professor" player
# player7 = Player(name="g", backend=TransformersConversational(),
#                  role_desc="",
#                  global_prompt=environment_description)
# Out:
# 2024-05-03 05:46:36.527892: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 05:46:36.528385: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 05:46:36.533982: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 05:46:37.351606: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# KeyboardInterrupt

# %%
from chatarena.environments.werewolf.werewolf import Werewolf

# env = Werewolf(player_names=[p.name for p in [player1, player2, player3, player4, player5, player6, player7]])
env = Werewolf(
    player_names=[p.name for p in [player1, player2, player3,player4,player5,player6,player7]],
    role_distribution = (2,5,0,0,0,0)
)
# Out:
# {'sean': (0, 'You are werewolf!'), 'adam': (0, 'You are werewolf!'), 'sid': (1, 'You are villager!'), 'sai': (1, 'You are villager!'), 'julia': (1, 'You are villager!'), 'marie': (1, 'You are villager!'), 'toby': (1, 'You are villager!')}
# 0
# get_observation
# None
# ['sean', 'adam', 'sid', 'sai', 'julia', 'marie', 'toby']
# False
# False
# False
# self._current_turn == 0
# You are playing a game called the Werewolf with some other players. This game is based on text conversations. Here are
# the game rules: Roles: The moderator is also host, he organised this game and you need to answer his instructions correctly.
# Don't talk with the moderator. There are five roles in the game, werewolf, villager, seer, guard and witch. There are two
# alternate phases in this game, daytime and dark. When it's dark: Your talking content with moderator is confidential. You
# needn't worry about other players and moderator knowing what you say and do. No need to worry about suspicions from
# ...

# %%
from chatarena.arena import Arena

# arena = Arena(players=[player1, player2, player3, player4, player5, player6, player7],
arena = Arena(players=[player1, player2, player3, player4, player5, player6, player7],
              environment=env, global_prompt=environment_description)
# Run the game for 10 steps
arena.run(num_steps=2)

# Alternatively, you can run your own main loop
for _ in range(2):
    arena.step()
    # Your code goes here ...
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# {'julia': (0, 'You are werewolf!'), 'toby': (0, 'You are werewolf!'), 'sean': (1, 'You are villager!'), 'marie': (1, 'You are villager!'), 'sai': (1, 'You are villager!'), 'adam': (1, 'You are villager!'), 'sid': (1, 'You are villager!')}
# 0
# get_observation
# None
# ['julia', 'toby', 'sean', 'marie', 'sai', 'adam', 'sid']
# False
# False
# False
# self._current_turn == 0
# You are playing a game called the Werewolf with some other players. This game is based on text conversations. Here are
# the game rules: Roles: The moderator is also host, he organised this game and you need to answer his instructions correctly.
# ...

# %%
game_log_idx = 5
arena.save_history(path=f"/projects/bcti/commons/chatarena-werewolf/logs/log_{game_log_idx}_hist.json")
arena.save_config(path=f"/projects/bcti/commons/chatarena-werewolf/logs/log_{game_log_idx}_config.json")
# Out:
# get_observation
# None
# ['julia', 'toby', 'sean', 'marie', 'sai', 'adam', 'sid']
# False
# False
# False
